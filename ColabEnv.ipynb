# %% [markdown]
# # ***Create virtual environment in Goggle Colab***
#
# ## Create virtual environment in Colab.
# ### Use **condacolab** to install Conda, using **pip**.
#
# ### Import the **condacolab** package. Call the **install()** function, to install the Conda into the *Colab notebook*.
#
# ### Create an *environment*, and install the required *packages* for the work.
#
# ## ***Attn:*** Every time you quit or reset the runtime, you wil need to install Conda again.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# Verify the Conda installation
# !conda --version

# Update conda
#!conda update -n base -c defaults conda
# !conda update -n base -c conda-forge conda --yes

#Locate the Conda package. Verify the Conda installation.
# !conda --version
# !conda info
# !which conda

# Path and version numbers for python
# !which python
# !python --version
# Out:
# ✨🍰✨ Everything looks OK!
# conda 23.11.0
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# conda 23.11.0
#
#      active environment : None
#        user config file : /root/.condarc
#  populated config files : /usr/local/.condarc
#           conda version : 23.11.0
#     conda-build version : not installed
#          python version : 3.10.13.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=broadwell
#                           __conda=23.11.0=0
#                           __glibc=2.35=0
#                           __linux=6.1.85=0
#                           __unix=0=0
#        base environment : /usr/local  (writable)
#       conda av data dir : /usr/local/etc/conda
# ...

# %% [markdown]
# ## Create the virtual environment file: **environment.yml**

# %%
# Create environment.yml
# !printf "name: ProSeisSN \n channels: \n   - defaults \n   - conda-forge \n dependencies: \n   - python>=3.12.5 \n   - cartopy \n   - pip \n   - pip: \n     - numpy>=1.15.0 \n     - scipy>=1.4.0 \n     - matplotlib \n     - seaborn \n     - obspy \n     - jupyterlab \n     - pandas \n     - pyqt5 \n     - pyrocko \n     - utm \n     - segyio \n" >> environment.yml
# !cat environment.yml

# Create environment ProSeisSN. Check environment info.
#!conda create --name ProSeisSN --file environment.yml --debug --yes
# !conda create --file environment.yml --debug --yes
# Ensure conda is initialized and list environments
# !conda init bash
# !conda env list
# Out:
# name: ProSeisSN
#  channels:
#    - defaults
#    - conda-forge
#  dependencies:
#    - python>=3.12.5
#    - cartopy
#    - pip
#    - pip:
#      - numpy>=1.15.0
#      - scipy>=1.4.0
#      - matplotlib
#      - seaborn
#      - obspy
#      - jupyterlab
#      - pandas
#      - pyqt5
#      - pyrocko
#      - utm
#      - segyio
# name: ProSeisSN
#  channels:
#    - defaults
#    - conda-forge
#  dependencies:
#    - python>=3.12.5
#    - cartopy
#    - pip
#    - pip:
#      - numpy>=1.15.0
#      - scipy>=1.4.0
#      - matplotlib
#      - seaborn
#      - obspy
#      - jupyterlab
#      - pandas
#      - pyqt5
#      - pyrocko
#      - utm
#      - segyio
# name: ProSeisSN
#  channels:
#    - defaults
#    - conda-forge
#  dependencies:
#    - python>=3.12.5
#    - cartopy
#    - pip
#    - pip:
#      - numpy>=1.15.0
#      - scipy>=1.4.0
#      - matplotlib
#      - seaborn
#      - obspy
#      - jupyterlab
#      - pandas
#      - pyqt5
#      - pyrocko
#      - utm
# ...
